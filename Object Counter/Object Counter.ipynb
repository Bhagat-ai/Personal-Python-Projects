# %%
import cv2 as cv
import imutils
from skimage.io import imread
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
def objectcount(img):
    img1=imread(img)
    img = cv.imread(img)
    imshow(img)
    gray_im = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    gray_correct = np.array(255 * (gray_im / 255) ** 1.2 , dtype='uint8')
    a=int(255)
    b=int(255)
    c=int(19)
    thresh = cv.adaptiveThreshold(gray_correct, a, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, b, c)
    thresh = cv.bitwise_not(thresh)
    kernel = np.ones((15,15), np.uint8)
    d=int(1)
    img_dilation = cv.dilate(thresh, kernel, iterations=d)
    img_erode = cv.erode(img_dilation,kernel, iterations=d)
    e=int(7)
    img_erode = cv.medianBlur(img_erode, e)
    ret, labels = cv.connectedComponents(img_erode)
    label_hue = np.uint8(179 * labels / np.max(labels))
    blank_ch = 255 * np.ones_like(label_hue)
    labeled_img = cv.merge([label_hue, blank_ch, blank_ch])
    labeled_img = cv.cvtColor(labeled_img, cv.COLOR_HSV2BGR)
    labeled_img[label_hue == 0] = 0
    plt.subplot(222)
    plt.title('Objects counted:'+ str(ret-1))
    plt.imshow(img1)
    print('The number of objects in the image are:', ret-1)
objectcount('patterns.png')
# Out:
# The number of objects in the image are: 6

# %%
import cv2 as cv
import imutils
from skimage.io import imread
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
def objectcount(img):
    img1=imread(img)
    img = cv.imread(img)
    imshow(img)
    gray_im = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    gray_correct = np.array(255 * (gray_im / 255) ** 1.2 , dtype='uint8')
    a=int(255)
    b=int(255)
    c=int(19)
    thresh = cv.adaptiveThreshold(gray_correct, a, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, b, c)
    thresh = cv.bitwise_not(thresh)
    kernel = np.ones((15,15), np.uint8)
    d=int(1)
    img_dilation = cv.dilate(thresh, kernel, iterations=d)
    img_erode = cv.erode(img_dilation,kernel, iterations=d)
    e=int(7)
    img_erode = cv.medianBlur(img_erode, e)
    ret, labels = cv.connectedComponents(img_erode)
    label_hue = np.uint8(179 * labels / np.max(labels))
    blank_ch = 255 * np.ones_like(label_hue)
    labeled_img = cv.merge([label_hue, blank_ch, blank_ch])
    labeled_img = cv.cvtColor(labeled_img, cv.COLOR_HSV2BGR)
    labeled_img[label_hue == 0] = 0
    plt.subplot(222)
    plt.title('Objects counted:'+ str(ret-1))
    plt.imshow(img1)
    print('The number of objects in the image are:', ret-1)
objectcount('polka.jpg')
# Out:
# The number of objects in the image are: 25

# %%
import cv2 as cv
import imutils
from skimage.io import imread
from pylab import *
import numpy as np
import matplotlib.pyplot as plt
def objectcount(img):
    img1=imread(img)
    img = cv.imread(img)
    imshow(img)
    gray_im = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
    gray_correct = np.array(255 * (gray_im / 255) ** 1.2 , dtype='uint8')
    a=int(255)
    b=int(255)
    c=int(19)
    thresh = cv.adaptiveThreshold(gray_correct, a, cv.ADAPTIVE_THRESH_GAUSSIAN_C, cv.THRESH_BINARY, b, c)
    thresh = cv.bitwise_not(thresh)
    kernel = np.ones((15,15), np.uint8)
    d=int(1)
    img_dilation = cv.dilate(thresh, kernel, iterations=d)
    img_erode = cv.erode(img_dilation,kernel, iterations=d)
    e=int(7)
    img_erode = cv.medianBlur(img_erode, e)
    ret, labels = cv.connectedComponents(img_erode)
    label_hue = np.uint8(179 * labels / np.max(labels))
    blank_ch = 255 * np.ones_like(label_hue)
    labeled_img = cv.merge([label_hue, blank_ch, blank_ch])
    labeled_img = cv.cvtColor(labeled_img, cv.COLOR_HSV2BGR)
    labeled_img[label_hue == 0] = 0
    plt.subplot(222)
    plt.title('Objects counted:'+ str(ret-1))
    plt.imshow(img1)
    print('The number of objects in the image are:', ret-1)
objectcount('numbers.png')
# Out:
# The number of objects in the image are: 5
